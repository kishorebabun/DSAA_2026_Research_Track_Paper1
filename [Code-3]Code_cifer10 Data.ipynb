# %%
from tabulate import tabulate
# =========================================================
# FIX CUDA ERROR
# =========================================================
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# =========================================================
# IMPORTS
# =========================================================
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import random
# Out:
# 2026-06-05 17:07:12.625045: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1780679232.644512     199 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1780679232.649593     199 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1780679232.664333     199 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1780679232.664402     199 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1780679232.664405     199 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1780679232.664407     199 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.

# %%
# =========================================================
# FIX RANDOMNESS
# =========================================================
np.random.seed(42)
tf.random.set_seed(42)
random.seed(42)

# %%
# =========================================================
# LOAD CIFAR-10
# =========================================================
from tensorflow.keras.datasets import cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# Normalize
x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

# Flatten labels
y_train = y_train.flatten()
y_test = y_test.flatten()

print("CIFAR-10 Loaded Successfully")
# Out:
# CIFAR-10 Loaded Successfully

# %%
# =========================================================
# CNN MODEL
# =========================================================
def create_model():

    model = keras.Sequential([

        keras.Input(shape=(32, 32, 3)),

        # BLOCK 1
        layers.Conv2D(32, (3,3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.Conv2D(32, (3,3), activation='relu', padding='same'),
        layers.MaxPooling2D((2,2)),
        layers.Dropout(0.25),

        # BLOCK 2
        layers.Conv2D(64, (3,3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.Conv2D(64, (3,3), activation='relu', padding='same'),
        layers.MaxPooling2D((2,2)),
        layers.Dropout(0.25),

        # BLOCK 3
        layers.Conv2D(128, (3,3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.Conv2D(128, (3,3), activation='relu', padding='same'),
        layers.MaxPooling2D((2,2)),
        layers.Dropout(0.25),

        layers.Flatten(),

        layers.Dense(256, activation='relu'),
        layers.Dropout(0.5),

        layers.Dense(10, activation='softmax')
    ])

    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=0.001),
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )

    return model

# %%
# =========================================================
# TRAIN MODEL
# =========================================================
model = create_model()

history = model.fit(
    x_train,
    y_train,
    epochs=50,
    batch_size=64,
    validation_split=0.1,
    verbose=1
)

# =========================================================
# EVALUATE
# =========================================================
loss, accuracy = model.evaluate(x_test, y_test, verbose=0)

print("\n==============================")
# Out:
# 2026-06-05 17:07:23.494798: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Epoch 1/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 162s 230ms/step - accuracy: 0.4838 - loss: 1.4216 - val_accuracy: 0.5830 - val_loss: 1.1369
# Epoch 3/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 160s 227ms/step - accuracy: 0.5933 - loss: 1.1626 - val_accuracy: 0.6692 - val_loss: 0.9510
# Epoch 4/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 157s 223ms/step - accuracy: 0.6576 - loss: 0.9983 - val_accuracy: 0.7170 - val_loss: 0.8099
# Epoch 5/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 160s 227ms/step - accuracy: 0.7052 - loss: 0.8736 - val_accuracy: 0.7334 - val_loss: 0.7920
# Epoch 6/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 158s 225ms/step - accuracy: 0.7470 - loss: 0.7449 - val_accuracy: 0.7794 - val_loss: 0.6473
# Epoch 8/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 159s 226ms/step - accuracy: 0.7669 - loss: 0.6862 - val_accuracy: 0.7692 - val_loss: 0.6679
# Epoch 9/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 163s 231ms/step - accuracy: 0.7781 - loss: 0.6486 - val_accuracy: 0.7726 - val_loss: 0.6892
# Epoch 10/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━
50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 158s 225ms/step - accuracy: 0.8965 - loss: 0.2982 - val_accuracy: 0.8272 - val_loss: 0.6182
# Epoch 34/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 160s 227ms/step - accuracy: 0.8980 - loss: 0.2972 - val_accuracy: 0.8276 - val_loss: 0.6297
# Epoch 35/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 156s 222ms/step - accuracy: 0.8993 - loss: 0.2895 - val_accuracy: 0.8408 - val_loss: 0.5892
# Epoch 36/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 160s 227ms/step - accuracy: 0.9016 - loss: 0.2879 - val_accuracy: 0.8478 - val_loss: 0.5794
# Epoch 37/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 156s 221ms/step - accuracy: 0.9034 - loss: 0.2740 - val_accuracy: 0.8084 - val_loss: 0.7237
# Epoch 38/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 160s 227ms/step - accuracy: 0.9035 - loss: 0.2766 - val_accuracy: 0.8382 - val_loss: 0.6102
# Epoch 39/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 157s 222ms/step - accuracy: 0.9060 - loss: 0.2719 - val_accuracy: 0.8498 - val_loss: 0.5479
# Epoch 40/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 158s 224ms/step - accuracy: 0.9067 - loss: 0.2663 - val_accuracy: 0.8440 - val_loss: 0.5758
# Epoch 41/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 158s 224ms/step - accuracy: 0.9107 - loss: 0.2560 - val_accuracy: 0.8480 - val_loss: 0.5777
# Epoch 42/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 158s 225ms/step - accuracy: 0.9110 - loss: 0.2556 - val_accuracy: 0.8450 - val_loss: 0.5988
# Epoch 43/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 161s 228ms/step - accuracy: 0.9107 - loss: 0.2553 - val_accuracy: 0.8388 - val_loss: 0.6159
# Epoch 44/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 161s 228ms/step - accuracy: 0.9128 - loss: 0.2520 - val_accuracy: 0.8412 - val_loss: 0.5916
# Epoch 45/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 158s 225ms/step - accuracy: 0.9157 - loss: 0.2412 - val_accuracy: 0.8436 - val_loss: 0.5933
# Epoch 46/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 159s 226ms/step - accuracy: 0.9151 - loss: 0.2440 - val_accuracy: 0.8486 - val_loss: 0.5975
# Epoch 47/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 159s 225ms/step - accuracy: 0.9186 - loss: 0.2343 - val_accuracy: 0.8486 - val_loss: 0.5788
# Epoch 48/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 161s 229ms/step - accuracy: 0.9181 - loss: 0.2391 - val_accuracy: 0.8496 - val_loss: 0.6107
# Epoch 49/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 160s 227ms/step - accuracy: 0.9219 - loss: 0.2283 - val_accuracy: 0.8486 - val_loss: 0.5859
# Epoch 50/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 153s 218ms/step - accuracy: 0.9167 - loss: 0.2383 - val_accuracy: 0.8532 - val_loss: 0.5705
#
# ==============================

# %%
# =========================================================
# EVALUATION
# =========================================================

loss, accuracy = model.evaluate(
    x_test,
    y_test,
    verbose=0
)

print("\nTest Accuracy:", round(accuracy * 100, 2), "%")
# Out:
# Test Accuracy: 84.34 %
